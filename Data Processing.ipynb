# %%
import pandas as pd
import numpy as np
from scipy import stats
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
quality_dict = {
    "-7": "minor",
    "-": "minor",
    "7": "major",
    "^7": "major",
    "sus": "sus",
    "5": "major",
    "add9": "major",
    "6": "major",
    "-9": "minor",
    "7sus": "sus",
    "9": "major",
    "^": "major",
    "^9": "major",
    "13": "major",
    "-11": "minor",
    "-6": "minor",
    "69": "major",
    "2": "major",
    "h7": "dim",
    "7#9": "major",
    "7b9": "major",
    "11": "major",
    "o7": "dim",
    "9sus": "sus",
    "13sus": "sus",
    "7#5": "aug",
    "+": "aug",
    "-^9": "minor",
    "-^7": "minor",
    "^13": "major",
    "7b9b13": "major",
    "13#11": "major",
    "h": "dim",
    "7#11": "major",
    "7b13": "major",
    "o": "dim",
    "-7b5": "dim",
    "^7#11": "major",
    "^9#11": "major",
    "7b5": "dim",
    "-69": "minor",
    "7b9#11": "major",
    "7b13sus": "sus",
    "9#11": "major",
    "13b9": "major",
    "-b6": "minor",
    "7b9sus": "sus",
    "7#9#5": "aug",
    "7alt": "aug",
    "7#9b5": "dim",
    '^7#5': "aug",
    '7b9b5': "dim",
    '7b9#5': "aug",
    '9#5': "aug",
    '7b9#9': "major",
    '7#9#11': "major",
    '7susadd3': "major",
    '13#9': "major",
    '9b5': "dim",
    '-#5': "minor",
    "": "major"
}

# %%
files = [r'data\jazz1350.json',r'data\pop400.json']

dfs = []
for file in files:
    with open(file) as json_file: 
        data_json = json.load(json_file)
        dfs.append(pd.DataFrame(data_json["songs"]))
df = pd.concat(dfs).reset_index(drop=True)

# %%
df
# Out:
#       bpm                     compStyle  \
# 0     160          Jazz-Medium Up Swing
# 1     140               Jazz-Bossa Nova
# 2     100             Jazz-Medium Swing
# 3     240           Jazz-Up Tempo Swing
# 4     100             Jazz-Medium Swing
# 5      80               Jazz-Slow Swing
# 6     100             Jazz-Medium Swing
# 7      60             Jazz-Ballad Swing
# 8     100             Jazz-Medium Swing
# 9     100             Jazz-Medium Swing
# 10    140               Jazz-Bossa Nova
# 11    100             Jazz-Medium Swing
# 12     60             Jazz-Ballad Swing
# 13    100             Jazz-Medium Swing
# 14     60             Jazz-Ballad Swing
# 15    100             Jazz-Medium Swing
# 16    140               Jazz-Bossa Nova
# 17     60             Jazz-Ballad Swing
# 18    180                    Jazz-Latin
# 19     60             Jazz-Ballad Swing
# 20    100             Jazz-Medium Swing
# 21    100             Jazz-Medium Swing
# 22    160          Jazz-Medium Up Swing
# 23    140                Jazz-Even 8ths
# 24     60             Jazz-Ballad Swing
# 25    100             Jazz-Medium Swing
# 26     60             Jazz-Ballad Swing
# 27    100             Jazz-Medium Swing
# 28    100             Jazz-Medium Swing
# 29    240           Jazz-Up Tempo Swing
# ...   ...                           ...
# 1723  125                      Pop-Rock
# 1724   88                      Pop-Rock
# 1725  175                      Pop-Rock
# 1726   97                      Pop-Soul
# 1727   93                      Pop-Soul
# 1728   84                      Pop-Soul
# 1729  132           Jazz-Swing Two/Four
# 1746             Joe Cocker (Preston, Fisher, Wilson)   Ab
# 1747                                    Wonder Stevie    B
# 1748                    Hot Chocolate (Wilson, Brown)    F
# 1749                          Queen (Freddie Mercury)   C-
# 1750                                      King Carole   Ab
# 1751      The Righteous Brothers(Spector, Mann, Weil)   Db
# 1752                        Elton John (John, Taupin)   Eb
#
#                                                   music  repeats  \
# 0     {'measures': [['F^7', 'Ab7'], ['Db^7', 'E7'], ...        0
# 1     {'measures': [['E-7'], ['E-7'], ['G-7'], ['G-7...        0
# 2     {'measures': [['A-7'], ['Db^7'], ['Bh7'], ['E7...        0
# 3     {'measures': [['C', 'A-7'], ['D-7', 'G7'], ['C...        0
# 4     {'measures': [['C9'], ['Eb-6'], ['C9'], ['Eb-6...        0
# 5     {'measures': [['D-7', 'G7b9'], ['C^7'], ['C#-7...        0
# 6     {'measures': [['C^7'], ['Gb7#11'], ['F^7'], ['...        0
# 7     {'measures': [['Bb6', 'Bo'], ['C-7'], ['F7', '...        0
# 8     {'measures': [['G-7'], ['C7'], ['F^7'], ['F^7'...        0
# 9     {'measures': [['Bb^7'], ['Eb-/Bb'], ['Bb^7'], ...        0
# 10    {'measures': [['A-7', 'C^7'], ['A-7', 'C^7'], ...        0
# 11    {'measures': [['C6'], ['C#o7'], ['D-6'], ['D#o...        0
# 12    {'measures': [['B7#11'], ['B7#11'], ['B7#11'],...        0
# 13    {'measures': [['F^7'], ['F#o7'], ['G-7'], ['C7...        0
# 14    {'measures': [['C^7'], ['Db7#11'], ['G-7', 'C7...        0
# 15    {'measures': [['C^7', 'G+'], ['C^7', 'Ebo7'], ...        0
# 16    {'measures': [['Eb9'], ['Eb-7'], ['Db^7'], ['D...        0
# 17    {'measures': [['Bb^7'], ['G-7', 'C7'], ['A-7']...        0
# 18    {'measures': [['Eb7'], ['D-'], ['Eb7'], ['D-']...        0
# 19    {'measures': [['Eb^7', 'C-7'], ['G-7', 'Bb-7',...        0
# 20    {'measures': [['A7', 'Bb13'], ['A7'], ['A-9'],...        0
# 21    {'measures': [['Ab^7', 'Eb7sus'], ['Ab^7', 'Eb...        0
# 22    {'measures': [['Bo7', 'Bb6'], ['F6/A', 'F6'], ...        0
# 23    {'measures': [['Bb7sus'], ['Bb7sus'], ['Bb7sus...        0
# 24    {'measures': [['F^7', 'F#o7'], ['G-7', 'C7b9']...        0
# 25    {'measures': [['D-'], ['D-^7'], ['D-7'], ['G7'...        0
# 26    {'measures': [['F^7'], ['Eb7/F'], ['F6'], ['G7...        0
# 27    {'measures': [['Eb^7'], ['Eb^7'], ['Eb^7', 'Ab...        0
# 28    {'measures': [['C^7'], ['C^7'], ['Bh7'], ['E7b...        0
# 29    {'measures': [['Eb^7'], ['Eb6'], ['Eb^7'], ['E...        0
# ...                                                 ...      ...
# 1723  {'measures': [['G#-7'], ['Eadd9'], ['F#'], ['F...        1
# 1724  {'measures': [['A'], ['D^7'], ['A'], ['D^7'], ...        1
# 1725  {'measures': [['E7'], ['E7'], ['E7'], ['E7'], ...        1
# 1726  {'measures': [['E^7'], ['E^7'], ['E^7'], ['E^7...        1
# 1727  {'measures': [['G#-11'], ['G#-11'], ['F#/G#'],...        1
# 1728  {'measures': [['Eb-7', 'B^7'], ['Ab-11', 'Ab/B...        1
# 1729  {'measures': [['Db'], ['Db'], ['Gb', 'Ab'], ['...        1
# 1730  {'measures': [['C'], ['C'], ['G'], ['G'], ['D-...        1
# 1731  {'measures': [['A-'], ['A-/G'], ['A-/F#'], ['F...        1
# 1732  {'measures': [['C', 'C/B'], ['C/A', 'C/G'], ['...        1
# 1733  {'measures': [['Dadd9'], ['G', 'D/F#'], ['E-7'...        1
# 1734  {'measures': [['A', 'D'], ['E'], ['A', 'D'], [...        1
# 1735  {'measures': [['C', 'F6/C', 'C'], ['C', 'F6/C'...        1
# 1736  {'measures': [['F-9'], ['G-7'], ['F-9'], ['G-7...        1
# 1737  {'measures': [['Ebsus', 'Eb'], ['Bbsus/Eb', 'E...        1
# 1738  {'measures': [['Eb-'], ['Eb-'], ['Cb^7'], ['Cb...        1
# 1739  {'measures': [['G'], ['D/F#'], ['C'], ['D', 'E...        1
# 1740  {'measures': [['F#-7', 'A'], ['Esus', 'Bsus'],...        1
# 1741  {'measures': [['Eb-7'], ['Eb-7'], ['Eb-7'], ['...        1
# 1742  {'measures': [['D7#9'], ['D7#9'], ['D7#9'], ['...        1
# 1743  {'measures': [['B'], ['B', 'Bsus'], ['B'], ['B...        1
# 1744  {'measures': [['F'], ['F'], ['F'], ['E-7', 'A7...        1
# 1745  {'measures': [['E'], ['E/Eb'], ['Db-', 'Db-9']...        1
# 1746  {'measures': [['Abadd9', 'Abadd9/Gb'], ['Db/F'...        1
# 1747  {'measures': [['B^9'], ['B^9'], ['F#7#5'], ['F...        1
# 1748  {'measures': [['F', 'F'], ['Bb', 'Bb'], ['F', ...        1
# 1749  {'measures': [['C-7', 'F-6/C'], ['C-7', 'F-6/C...        1
# 1750  {'measures': [['Ab'], ['Db/Ab'], ['Ab'], ['G-'...        1
# 1751  {'measures': [['Cb/Db'], ['Cb/Db'], ['Db'], ['...        1
# 1752  {'measures': [['Eb', 'Ab/Eb'], ['Bb/Eb', 'Ab/E...        1
#
#                 style                                  title  transpose
# 0     Medium Up Swing                                   26-2          5
# 1          Bossa Nova                         500 Miles High          7
# 2               Waltz                              502 Blues          0
# 3      Up Tempo Swing                      52nd Street Theme          0
# 4        Medium Swing                           9.20 Special          0
# 5          Slow Swing                               A Ballad          0
# 6        Medium Swing                 A Beautiful Friendship          0
# 7              Ballad                         A Blossom Fell         10
# 8        Medium Swing                        A Certain Smile          5
# 9               Waltz                        A Child Is Born         10
# 10         Bossa Nova                           A Felicidade          0
# 11       Medium Swing                         A Fine Romance          0
# 12             Ballad           A Flower Is A Lovesome Thing          1
# 13       Medium Swing                            A Foggy Day          5
# 14             Ballad                    A Ghost Of A Chance          0
# 15       Medium Swing             A Kiss To Build A Dream On          0
# 16         Bossa Nova                          A Little Tear          1
# 17             Ballad       A Lovely Way To Spend An Evening          5
# 18              Latin                     A Night In Tunisia          5
# 19             Ballad  A Nightingale Sang In Berkeley Square          3
# 20       Medium Swing         A Pretty Girl Is Like A Melody          7
# 21       Medium Swing                         A Sleepin' Bee          8
# 22    Medium Up Swing                           A Smooth One          5
# 23          Even 8ths                  A Sound For Sore Ears          3
# 24             Ballad                  A Sunday Kind Of Love          5
# 25              Waltz                       A Taste Of Honey          5
# 26             Ballad                        A Time For Love          5
# 27       Medium Swing                      A Tisket A Tasket          3
# 28       Medium Swing                     A Weaver Of Dreams          0
# 29     Up Tempo Swing             A Wonderful Day Like Today          3
# ...               ...                                    ...        ...
# 1723             Rock              We Weren't Born To Follow         11
# 1724              Pop                  We've Only Just Begun          4
# 1725              RnB                           What'd I Say          4
# 1726             Soul                        What's Going On          4
# 1727         Rock Pop          What's Love Got To Do With It         11
# 1728       Pop Ballad             When I Give My Love To You          6
# 1729         Rock Pop                            When I'm 64          1
# 1730              RnB                  Where Did Our Love Go          0
# 1731         Rock Pop           While My Guitar Gently Weeps          0
# 1732             Rock               Whiter Shade of Pale, A           0
# 1733        Folk Rock                               Who Says          2
# 1734             Rock                             Wild Thing          9
# 1735              Pop        Will You Still Love Me Tomorrow          0
# 1736            Waltz                     Wives And Lovers 1          3
# 1737      Rock Ballad                                  Woman          3
# 1738       Pop Ballad                          Woman In Love          6
# 1739       Pop Ballad                      Wonderful Tonight          7
# 1740             Rock                             Wonderwall          9
# 1741             Folk                              Woodstock          6
# 1742         Rock Pop                              Word, The          2
# 1743              Pop                                 Yellow         11
# 1744         Rock Pop                              Yesterday          5
# 1745              Pop                    Yesterday Once More          4
# 1746              Pop                   You Are So Beautiful          8
# 1747             Soul        You Are The Sunshine Of My Life         11
# 1748              Pop                         You Sexy Thing          5
# 1749             Rock                You Take My Breath Away          3
# 1750        Folk Rock                    You've Got A Friend          8
# 1751              Pop        You've Lost That Lovin' Feelin'          1
# 1752              Pop                              Your song          3
#
# [1753 rows x 9 columns]

# %%
def get_chordlist(music):
    """
    input: music dict object, containing "measures" element
    output: returns python list of sequence of chords in the song, with no sequential duplicates
    """   
    #collapses all measures into single array
    chords = []
    for measure in music["measures"]:
        for chord in measure:
            chords.append(chord)
    
    #remove None
    chords = [chord for chord in chords if chord != None]

    return chords

# %%
def get_interval(startnote, endnote):
    """
    startnote and endnote are notes (like G or Eb or F#)
    returns: number of semitones between startnote and endnote, counting upwards
    """
    notesdict = {
        "C": 0,
        "C#": 1,
        "Db": 1,  
        "D": 2,
        "D#": 3,
        "Eb": 3,
        "E": 4,
        "F": 5,
        "F#": 6,
        "Gb": 6,
        "G": 7,
        "G#": 8,
        "Ab": 8,
        "A": 9,
        "A#": 10,
        "Bb": 10,
        "B": 11,
    }
    try:
        return (notesdict[endnote] - notesdict[startnote] + 5) % 12 -5
    except:
        return 0

# %%
print(get_interval("C", "F#"))
print(get_interval("C", "G"))
# Out:
# 6
# -5

# %%
df.shape
# Out:
# (1753, 9)

# %%
def get_chord_change(row):
    try:
        ""
    except:
        return "none_0_none"

songdfs = []
for i in range(df.shape[0]):
#for i in range(3,4):
    dfdict = {
        "song_index": i,
        #"title": df["title"][i],
        "chord": get_chordlist(df["music"][i]) 
    }
    songdf = pd.DataFrame(dfdict)
    
    chord_info = songdf["chord"].str.extract("^([ABCDEFG][b#]?)([^/]*)?/?(.*)?", expand=True)
    songdf["quality"] = chord_info[1]
    songdf["inversion"] = chord_info[2]
    songdf["root"] = chord_info[0]
    songdf["triad_quality"] = songdf["quality"].apply(lambda x: quality_dict[x])
    #create columns for previous chord
    songdf["prev_root"] = songdf['root'].shift(1, fill_value="none")
    songdf["prev_triad_quality"] = songdf['triad_quality'].shift(1, fill_value="none")
    
    #drop rows where previous and current chord root/triad-quality are identical
    duplicates = (songdf["root"]==songdf["prev_root"]) & (songdf["triad_quality"]==songdf["prev_triad_quality"])
    songdf = songdf[~duplicates].copy().reset_index(drop=True)
    songdf["chord_sequence"] = songdf.index
    songdf["interval"] = songdf.apply(lambda x: get_interval(x["prev_root"], x["root"]), axis=1)
    songdf["chord_change"] = songdf["prev_triad_quality"] + "_" + songdf["interval"].astype(str) +"_"+ songdf["triad_quality"]
    songdfs.append(songdf)

chordsdf =  pd.concat(songdfs).reset_index(drop=True)

# %%
chordsdf.head(30)
# Out:
#     song_index chord quality inversion root triad_quality prev_root  \
# 0            0   F^7      ^7              F         major      none
# 1            0   Ab7       7             Ab         major         F
# 2            0  Db^7      ^7             Db         major        Ab
# 3            0    E7       7              E         major        Db
# 4            0   A^7      ^7              A         major         E
# 5            0    C7       7              C         major         A
# 6            0   C-7      -7              C         minor         C
# 7            0    F7       7              F         major         C
# 8            0  Bb^7      ^7             Bb         major         F
# 9            0   Db7       7             Db         major        Bb
# 10           0  Gb^7      ^7             Gb         major        Db
# 11           0    A7       7              A         major        Gb
# 12           0   D-7      -7              D         minor         A
# 13           0    G7       7              G         major         D
# 14           0   G-7      -7              G         minor         G
# 15           0    C7       7              C         major         G
# 16           0   F^7      ^7              F         major         C
# 17           0   Ab7       7             Ab         major         F
# 18           0  Db^7      ^7             Db         major        Ab
# 19           0    E7       7              E         major        Db
# 20           0   A^7      ^7              A         major         E
# 21           0    C7       7              C         major         A
# 22           0   C-7      -7              C         minor         C
# 23           0    F7       7              F         major         C
# 24           0  Bb^7      ^7             Bb         major         F
# 25           0   Ab7       7             Ab         major        Bb
# 26           0  Db^7      ^7             Db         major        Ab
# 27           0    E7       7              E         major        Db
# 28           0   A^7      ^7              A         major         E
# 29           0    C7       7              C         major         A
#
#    prev_triad_quality  chord_sequence  interval    chord_change
# 0                none               0         0    none_0_major
# 1               major               1         3   major_3_major
# 2               major               2         5   major_5_major
# 3               major               3         3   major_3_major
# 4               major               4         5   major_5_major
# 5               major               5         3   major_3_major
# 6               major               6         0   major_0_minor
# 7               minor               7         5   minor_5_major
# 8               major               8         5   major_5_major
# 9               major               9         3   major_3_major
# 10              major              10         5   major_5_major
# 11              major              11         3   major_3_major
# 12              major              12         5   major_5_minor
# 13              minor              13         5   minor_5_major
# 14              major              14         0   major_0_minor
# 15              minor              15         5   minor_5_major
# 16              major              16         5   major_5_major
# 17              major              17         3   major_3_major
# 18              major              18         5   major_5_major
# 19              major              19         3   major_3_major
# 20              major              20         5   major_5_major
# 21              major              21         3   major_3_major
# 22              major              22         0   major_0_minor
# 23              minor              23         5   minor_5_major
# 24              major              24         5   major_5_major
# 25              major              25        -2  major_-2_major
# 26              major              26         5   major_5_major
# 27              major              27         3   major_3_major
# 28              major              28         5   major_5_major
# 29              major              29         3   major_3_major

# %%
chordsdf["chord_change"].value_counts().head(15)
# Out:
# major_5_major     14435
# minor_5_major     10531
# major_5_minor      5421
# major_-5_major     4965
# major_2_major      2923
# major_-3_minor     2796
# major_-1_major     2686
# minor_5_minor      2454
# major_2_minor      2450
# major_-2_major     2165
# dim_5_major        1996
# major_-5_minor     1885
# major_0_minor      1592
# major_-1_minor     1531
# minor_-4_major     1528
# Name: chord_change, dtype: int64

# %%
songs = df.drop(["music", "transpose", "repeats"],axis=1)
songs
songs["song_index"] = songs.index

# %%
songs
# Out:
#       bpm                     compStyle  \
# 0     160          Jazz-Medium Up Swing
# 1     140               Jazz-Bossa Nova
# 2     100             Jazz-Medium Swing
# 3     240           Jazz-Up Tempo Swing
# 4     100             Jazz-Medium Swing
# 5      80               Jazz-Slow Swing
# 6     100             Jazz-Medium Swing
# 7      60             Jazz-Ballad Swing
# 8     100             Jazz-Medium Swing
# 9     100             Jazz-Medium Swing
# 10    140               Jazz-Bossa Nova
# 11    100             Jazz-Medium Swing
# 12     60             Jazz-Ballad Swing
# 13    100             Jazz-Medium Swing
# 14     60             Jazz-Ballad Swing
# 15    100             Jazz-Medium Swing
# 16    140               Jazz-Bossa Nova
# 17     60             Jazz-Ballad Swing
# 18    180                    Jazz-Latin
# 19     60             Jazz-Ballad Swing
# 20    100             Jazz-Medium Swing
# 21    100             Jazz-Medium Swing
# 22    160          Jazz-Medium Up Swing
# 23    140                Jazz-Even 8ths
# 24     60             Jazz-Ballad Swing
# 25    100             Jazz-Medium Swing
# 26     60             Jazz-Ballad Swing
# 27    100             Jazz-Medium Swing
# 28    100             Jazz-Medium Swing
# 29    240           Jazz-Up Tempo Swing
# ...   ...                           ...
# 1723  125                      Pop-Rock
# 1724   88                      Pop-Rock
# 1725  175                      Pop-Rock
# 1726   97                      Pop-Soul
# 1727   93                      Pop-Soul
# 1728   84                      Pop-Soul
# 1729  132           Jazz-Swing Two/Four
# 1730  138          Jazz-Medium Up Swing
# 1731  115                      Pop-Rock
# 1732   75                      Pop-Rock
# 1733  180                   Pop-Country
# 1734  102                      Pop-Rock
# 1735   79                      Pop-Rock
# 1736  134             Jazz-Medium Swing
# 1737   85                      Pop-Rock
# 1738   85                      Pop-Rock
# 1739   96                      Pop-Rock
